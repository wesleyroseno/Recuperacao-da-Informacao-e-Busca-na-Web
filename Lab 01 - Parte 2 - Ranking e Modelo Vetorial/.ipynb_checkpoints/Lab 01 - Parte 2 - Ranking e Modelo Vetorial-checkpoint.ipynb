# %%
import numpy as np

# %%
import pandas as pd

# %%
news = pd.read_csv('noticias_estadao.csv', sep=',', index_col='idNoticia')

# %%
news
# Out:
#                       timestamp  \
# idNoticia
# 1          2014-12-31T00:00:00Z
# 2          2014-12-31T00:00:00Z
# 3          2014-12-31T00:00:00Z
# 4          2014-12-31T00:00:00Z
# 5          2014-12-31T00:00:00Z
# 6          2014-12-31T00:00:00Z
# 7          2014-12-31T00:00:00Z
# 8          2014-12-31T00:00:00Z
# 9          2014-12-31T00:00:00Z
# 10         2014-12-31T00:00:00Z
# 11         2014-12-31T00:00:00Z
# 12         2014-12-31T00:00:00Z
# 13         2014-12-31T00:00:00Z
# 14         2014-12-31T00:00:00Z
# 15         2014-12-31T00:00:00Z
# 16         2014-12-31T00:00:00Z
# 17         2014-12-31T00:00:00Z
# 18         2014-12-31T00:00:00Z
# 19         2014-12-31T00:00:00Z
# 20         2014-12-31T00:00:00Z
# 21         2014-12-30T00:00:00Z
# 22         2014-12-30T00:00:00Z
# 23         2014-12-30T00:00:00Z
# 24         2014-12-30T00:00:00Z
# 25         2014-12-30T00:00:00Z
# 26         2014-12-30T00:00:00Z
# 27         2014-12-30T00:00:00Z
# 28         2014-12-30T00:00:00Z
# 29         2014-12-30T00:00:00Z
# 30         2014-12-30T00:00:00Z
# ...                         ...
# 8687       2014-01-05T00:00:00Z
# 8688       2014-01-05T00:00:00Z
# 8689       2014-01-05T00:00:00Z
# 8690       2014-01-05T00:00:00Z
# 8691       2014-01-05T00:00:00Z
# 8692       2014-01-05T00:00:00Z
# 8693       2014-01-05T00:00:00Z
# 8694       2014-01-05T00:00:00Z
# 8695       2014-01-05T00:00:00Z
# 8696       2014-01-05T00:00:00Z
# 8697       2014-01-04T00:00:00Z
# 8698       2014-01-04T00:00:00Z
# 8699       2014-01-04T00:00:00Z
# 8700       2014-01-04T00:00:00Z
# 8701       2014-01-04T00:00:00Z
# 8702       2014-01-04T00:00:00Z
# 8703       2014-01-04T00:00:00Z
# 8704       2014-01-04T00:00:00Z
# 8705       2014-01-04T00:00:00Z
# 8706       2014-01-04T00:00:00Z
# 8707       2014-01-03T00:00:00Z
# 8708       2014-01-03T00:00:00Z
# 8709       2014-01-03T00:00:00Z
# 8710       2014-01-03T00:00:00Z
# 8711       2014-01-03T00:00:00Z
# 8712       2014-01-03T00:00:00Z
# 8713       2014-01-03T00:00:00Z
# 8714       2014-01-03T00:00:00Z
# 8715       2014-01-03T00:00:00Z
# 8716       2014-01-03T00:00:00Z
#
#                                                       titulo  \
# idNoticia
# 1             PT espera 30 mil pessoas em festa na Esplanada
# 2                     Alckmin toma posse de olho no Planalto
# 3          Seis obstáculos e desafios do segundo mandato ...
# 4
# 5
# 6
# 7          Veja os desafios dos governadores que assumem ...
# 8          PT impulsiona cerimônia de posse da Dilma nas ...
# 9
# 10         Dilma veta projeto de Suplicy que cria linha o...
# 11         Dilma anuncia 14 ministros e conclui reforma m...
# 12         Dilma anuncia últimos 14 ministros e fecha equipe
# 13         Ex-governador critica Alckmin pela falta de ág...
# 14         Veja lista completa de ministros anunciados po...
# 15         'PT não pode se queixar', afirma futuro articu...
# 16         Planalto confirma Juca Ferreira no Ministério ...
# 17         Pimentel divulga nomes do secretariado do gove...
# 18         Com recusa de Celso Amorim, Figueiredo deve fi...
# 19               Ala do PT pede saída de Ideli de ministério
# 20         Cid Gomes anunciará novo piso para professores...
# 21         Além de ministério, PRB ganha pastas estaduais...
# 22         Ministro não precisa ser expert, afirma prefei...
# 23         Dilma deixa Lula e ala majoritária do PT de fo...
# 24
# 25         Lei de Roseana dá à ex-governadora direito a n...
# 26         Alckmin chama presidente do PSDB paulista para...
# 27         E-mails indicam ‘atuação direta’ de cartel no ...
# 28         Menor prestígio e verba faz diplomatas buscare...
# 29         'Obras de Alckmin terão significado para todo ...
# 30         Cúpula da política externa proíbe uso de Faceb...
# ...                                                      ...
# 8687       Dados ajudam a  quebrar mitos da  política nac...
# 8688       Eleição municipal e pequenas cidades induzem f...
# 8689       11% dos eleitores do País são filiados a legen...
# 8690        Adesão cresce em regiões de maior escolaridade
# 8691       'Se sentença seguiu as regras, é difícil haver...
# 8692                                Abstinência programada
# 8693           Siglas descumprem cota feminina em propaganda
# 8694       Bancada de mulheres no Brasil é inferior à méd...
# 8695       Em prisão domiciliar, Genoino muda endereço pe...
# 8696       Câmara não cumpre promessa de economia de R$ 2...
# 8697       'Aliança com tucanos é a nova política', diz C...
# 8698               Com base oscilante, Dilma usa menos PEC
# 8699       Aos 139 anos, 'Estado' preserva defesa da libe...
# 8700              Dilma aprovou menos emendas que Lula e FHC
# 8701       Câmara deixa de cumprir promessa de economia d...
# 8702       PSB prepara anúncio de Marina como vice de Cam...
# 8703       Campos empossa novos secretários em clima de c...
# 8704       Alckmin volta a dizer que espera 'investigação...
# 8705       Governo atua para adiar leis sensíveis a sindi...
# 8706             Calendário curto trava pauta do Congresso
# 8707       Presidenciáveis privilegiam o Sudeste no cumpr...
# 8708       Executivo da Siemens teve ordem para destruir ...
# 8709       Governo tenta barrar projeto sobre greve de se...
# 8710       Falta de acordo deve se intensificar no Congresso
# 8711
# 8712              Itamaraty recupera status com o Planalto
# 8713             No Congresso, até ruralistas são 'verdes'
# 8714                  Indústria também tem lista de demandas
# 8715       Ambientalistas criam pontes com oposição para ...
# 8716       Ministros candidatos na eleição de outubro têm...
#
#                                                    subTitulo  \
# idNoticia
# 1          Objetivo é demonstrar apoio popular a Dilma e ...
# 2          Governador reeleito tenta amarrar tucanos paul...
# 3          Em meio a escândalo de corrupção, presidente t...
# 4          Veja as principais fotos do dia e dos eventos ...
# 5          Veja as principais fotos do dia e dos eventos ...
# 6          Veja as principais fotos do dia e dos eventos ...
# 7
# 8          Já entre os 27 governadores eleitos, apenas se...
# 9          Em setembro de 2014, após conceder entrevista ...
# 10         Proposta havia sido aprovada no Senado depois ...
# 11         Mauro Vieira vai assumir a pasta das Relações ...
# 12         Mauro Vieira vai assumir a pasta das Relações ...
# 13         Apesar das declarações, Cláudio Lembo diz que ...
# 14         Dos 14 que faltavam, 13 permanecem no cargo pa...
# 15         Novo titular da pasta responsável pela relação...
# 16         Impasse sobre Itamaraty emperra reforma minist...
# 17         Governador também anunciou a criação das pasta...
# 18         Dilma teria ficado sem alternativas para subst...
# 19         Setorial de Direitos Humanos cobra 'sinalizaçã...
# 20         Futuro Ministro da Educação se reuniu com atua...
# 21         Após conquistar posição no lugar do PC do B, s...
# 22         'Se o sujeito for bom gestor, vai muito bem',d...
# 23         Ao confirmar Pepe Vargas na pasta da articulaç...
# 24         Chefe da Casa Civil do governo Alckmin disse q...
# 25         Roseana tem pensão vitalícia de R$ 24 mil por ...
# 26         Deputado federal Duarte Nogueira irá comandar ...
# 27         Polícia Federal apreendeu em computador do núm...
# 28         Com orçamento reduzido no governo Dilma em com...
# 29         Futuro secretário destaca impacto nacional em ...
# 30         Órgão tem conduzido crise interna com alertas ...
# ...                                                      ...
# 8687
# 8688       Levantamento revela que 70% das 13,8 milhões d...
# 8689
# 8690
# 8691       Secretário-geral indica ser improvável que OEA...
# 8692
# 8693       Só em São Paulo, um em cada quatro partidos de...
# 8694       Para especialistas ouvidas pelo 'Estado', só u...
# 8695       A decisão foi comunicada na véspera ao STF; ad...
# 8696
# 8697       Governador de Pernambuco exalta ingresso do PS...
# 8698       Atual governo deve terminar com 9 emendas cons...
# 8699       Fundado em 4 de janeiro de 1875 por um grupo d...
# 8700       Atual presidente deve encerrar o mandato com 9...
# 8701       Novo sistema de registro de frequência de func...
# 8702       Após ex-ministra vetar o apoio da sigla à reel...
# 8703
# 8704       Declaração foi dada após 'Estado' revelar que ...
# 8705       Regulação de greve no   setor público e propos...
# 8706       Eleições e Copa reduzem dias de votação e difi...
# 8707       Prováveis candidatos ao Planalto viajaram mais...
# 8708       Sergio de Bona diz à PF que foi instruído a el...
# 8709
# 8710
# 8711       Às segundas e sextas-feiras, parlamentares do ...
# 8712       Figueiredo ainda tem problemas a resolver na d...
# 8713
# 8714       Assim como agronegócio, que já faz encontros c...
# 8715       Descontentes com a atuação do governo Dilma no...
# 8716       A reforma política pode ocorrer antes do fim d...
#
#                                                     conteudo  \
# idNoticia
# 1          BRASÍLIA - Após o desgaste provocado com o lan...
# 2          Reeleito em outubro, o governador tucano Geral...
# 3            1. Rearranjo das contas A nova equipe econôm...
# 4
# 5
# 6
# 7          No Acre, governador reeleito quer erradicar an...
# 8          Os perfis da presidente Dilma Rousseff, nas re...
# 9
# 10         A presidente Dilma Rousseff vetou integralment...
# 11         A presidente Dilma Rousseff concluiu nesta qua...
# 12         O Palácio do Planalto anunciou no fim da manhã...
# 13         O ex-governador e integrante da Executiva do P...
# 14         Veja a lista de ministros já anunciados pela p...
# 15         Escolhido pela presidente Dilma Rousseff para ...
# 16         (Atualizado às 6h18) BRASÍLIA - Na véspera de ...
# 17         BELO HORIZONTE - O governador eleito de Minas ...
# 18         BRASÍLIA - O ministro das Relações Exteriores,...
# 19         O setorial de Direitos Humanos do Partido dos ...
# 20         Convidado para ocupar o Ministério da Educação...
# 21         Depois de garantir que comandará o Ministério ...
# 22         Um dos principais cabos eleitorais da presiden...
# 23         BRASÍLIA - Ao anunciar ontem mais sete nomes p...
# 24
# 25         BRASÍLIA - A ex-governadora do Maranhão Rosean...
# 26         Atualizado às 21h10. Faltando apenas dois dias...
# 27         Por Ricardo Brandt, Fausto Macedo e Julia Affo...
# 28         A queda de prestígio da diplomacia no governo ...
# 29         Principal braço político do governador Geraldo...
# 30         Para tentar abafar a crise, assessores do mini...
# ...                                                      ...
# 8687       Essa mesma lógica derruba a ideia comum de que...
# 8688       A cada quatro anos, uma onda de filiações a pa...
# 8689       Há, porém, variações regionais nesse fenômeno....
# 8690       No Rio Grande do Sul, o índice de 15,8% do ele...
# 8691       Secretário-geral da Organização dos Estados Am...
# 8692       O governo começa a ter de sacrificar posições,...
# 8693       SÃO PAULO - O Brasil elegeu em 2010 uma mulher...
# 8694       SÃO PAULO - Apenas 8,9% das vagas da Câmara e ...
# 8695       Condenado em regime semiaberto no processo do ...
# 8696       No caso do cotão, como são chamados os benefíc...
# 8697       A posse de seis novos integrantes do secretari...
# 8698       A presidente Dilma Rousseff adotou como estrat...
# 8699       São 139 anos de fundação e 134 anos de vida in...
# 8700       A presidente Dilma Rousseff adotou como estrat...
# 8701       Brasília - A promessa do presidente da Câmara,...
# 8702       O PSB espera que Marina Silva anuncie publicam...
# 8703       Murilo Guerra, ex-superintendente do Sebrae em...
# 8704       SÃO PAULO - O governador de São Paulo, Geraldo...
# 8705       Além dos impasses político-eleitorais da base ...
# 8706       O tensionamento eleitoral que impediu que proj...
# 8707       A região Sudeste foi o principal destino das v...
# 8708       O gerente-geral da área de projetos corporativ...
# 8709       O caso mais evidente foi no debate sobre a reg...
# 8710       Casos exemplares são os projetos que mexem com...
# 8711
# 8712       Em agosto, quando assumiu o Ministério das Rel...
# 8713       Alguém definiria como verdes os senadores Fern...
# 8714       Em um esforço para pautar o debate político da...
# 8715       Aliados incondicionais da ex-ministra Marina S...
# 8716       SÃO PAULO - A presidente Dilma Rousseff não de...
#
#                                                          url
# idNoticia
# 1          http://politica.estadao.com.br/noticias/geral,...
# 2          http://politica.estadao.com.br/noticias/geral,...
# 3          http://politica.estadao.com.br/noticias/geral,...
# 4          http://fotos.estadao.com.br/fotos/politica,dil...
# 5          http://fotos.estadao.com.br/fotos/politica,dil...
# 6          http://fotos.estadao.com.br/fotos/politica,dil...
# 7          http://politica.estadao.com.br/noticias/geral,...
# 8          http://politica.estadao.com.br/noticias/geral,...
# 9          http://tv.estadao.com.br/videos,politica,dilma...
# 10         http://politica.estadao.com.br/noticias/geral,...
# 11         http://politica.estadao.com.br/noticias/geral,...
# 12         http://politica.estadao.com.br/noticias/geral,...
# 13         http://politica.estadao.com.br/blogs/julia-dua...
# 14         http://politica.estadao.com.br/noticias/geral,...
# 15         http://politica.estadao.com.br/noticias/geral,...
# 16         http://politica.estadao.com.br/noticias/geral,...
# 17         http://politica.estadao.com.br/noticias/geral,...
# 18         http://politica.estadao.com.br/noticias/geral,...
# 19         http://politica.estadao.com.br/noticias/geral,...
# 20         http://politica.estadao.com.br/noticias/geral,...
# 21         http://politica.estadao.com.br/noticias/geral,...
# 22         http://politica.estadao.com.br/noticias/geral,...
# 23         http://politica.estadao.com.br/noticias/geral,...
# 24         http://tv.estadao.com.br/videos,politica,para-...
# 25         http://politica.estadao.com.br/noticias/geral,...
# 26         http://politica.estadao.com.br/noticias/geral,...
# 27         http://politica.estadao.com.br/blogs/fausto-ma...
# 28         http://politica.estadao.com.br/noticias/geral,...
# 29         http://politica.estadao.com.br/noticias/geral,...
# 30         http://politica.estadao.com.br/noticias/geral,...
# ...                                                      ...
# 8687       http://politica.estadao.com.br/noticias/eleico...
# 8688       http://politica.estadao.com.br/noticias/eleico...
# 8689       http://politica.estadao.com.br/noticias/eleico...
# 8690       http://politica.estadao.com.br/noticias/eleico...
# 8691       http://politica.estadao.com.br/noticias/eleico...
# 8692       http://politica.estadao.com.br/noticias/eleico...
# 8693       http://politica.estadao.com.br/noticias/geral,...
# 8694       http://politica.estadao.com.br/noticias/geral,...
# 8695       http://politica.estadao.com.br/noticias/geral,...
# 8696       http://politica.estadao.com.br/noticias/geral,...
# 8697       http://politica.estadao.com.br/noticias/eleico...
# 8698       http://politica.estadao.com.br/noticias/eleico...
# 8699       http://politica.estadao.com.br/noticias/geral,...
# 8700       http://politica.estadao.com.br/noticias/geral,...
# 8701       http://politica.estadao.com.br/noticias/geral,...
# 8702       http://politica.estadao.com.br/noticias/geral,...
# 8703       http://politica.estadao.com.br/noticias/geral,...
# 8704       http://politica.estadao.com.br/noticias/geral,...
# 8705       http://politica.estadao.com.br/noticias/eleico...
# 8706       http://politica.estadao.com.br/noticias/eleico...
# 8707       http://politica.estadao.com.br/noticias/eleico...
# 8708       http://politica.estadao.com.br/noticias/eleico...
# 8709       http://politica.estadao.com.br/noticias/geral,...
# 8710       http://politica.estadao.com.br/noticias/geral,...
# 8711       http://tv.estadao.com.br/videos,politica,os-re...
# 8712       http://politica.estadao.com.br/noticias/eleico...
# 8713       http://politica.estadao.com.br/noticias/eleico...
# 8714       http://politica.estadao.com.br/noticias/eleico...
# 8715       http://politica.estadao.com.br/noticias/eleico...
# 8716       http://politica.estadao.com.br/noticias/geral,...
#
# [8716 rows x 5 columns]

# %%
news = pd.read_csv('estadao_noticias_eleicao.csv', sep=',', index_col='idNoticia')

# %%
news = news.sort_index(ascending=True)

# %%
news = news.replace(np.nan, '', regex=True)

# %%
news.ix[1][0][0][0:-1]
# Out:
# '2014-12-31t00:00:00'

# %%
len(news.ix[1][0][0][0])
# Out:
# 1

# %% [markdown]
# # Transforma o texto de cada celula da tabela, em uma lista das palavras do texto, em letras minusculas. E remove pontos finais de cada palavra.

# %%
for i in range(1, len(news) + 1):
    for j in range(len(news.ix[i])):        
        news.ix[i][j] = str(news.ix[i][j]) #força que a celula seja uma string, para uso da função lower()
        news.ix[i][j] = list(set(news.ix[i][j].lower().split(" ")))
# Out:
# /opt/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
for i in range(1, len(news) + 1):
    for j in range(len(news.ix[i])):
        for k in range(len(news.ix[i][j])):
            if (news.ix[i][j][k][-1] == '.'):
                news.ix[i][j][k] = news.ix[i][j][k][0:-1] #remove os "." final das palaras
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-203-83b09babeb8f> in <module>()
#       2     for j in range(len(news.ix[i])):
#       3         for k in range(len(news.ix[i][j])):
# ----> 4             if (news.ix[i][j][k][-1] == '.'):
#       5                 news.ix[i][j][k] = news.ix[i][j][k][0:-1] #remove os "." final das palaras
#
# IndexError: string index out of range

# %% [markdown]
# # Cria um índice invertido das palavras dos documentos, onde associa cada palavra aos documentos que ela se encontra.

# %%
reference_list = {}

for i in range(1, len(news) + 1):
    for j in range(len(news.ix[i])):
        for k in news.ix[i][j]:
            if(reference_list.setdefault(k, -1) == -1):
                reference_list[k] = set()
                
            reference_list[k].add(i)

# %% [markdown]
# # FUNÇÕS DE BUSCA

# %%
def search_one_term(word):
    return list(reference_list[word])

# %%
def search_or_n_terms(words):
    result = reference_list[words[0]]
    
    for i in range(1, len(words)):
                result = np.union1d(list(result), list(reference_list[words[i]]))
                # result é o resultado de sucessivas buscas AND das palavras
                
                return list(result)

# %%
def smaller_terms(words):
    smaller = 0
    
    for i in range(1, len(words)):
            if (len(reference_list[words[smaller]]) > len(reference_list[words[i]])): 
                    smaller = i # posição da palavra com menos documentos
                    
    words[0], words[smaller] = words[smaller], words[0]
    #coloca o termo presente em menos documentos na posição inicial da lista
                    
    return None # função com efeito colateral

# %%
def search_and_n_terms(words):
    if (len(words) > 2):
        smaller = smaller_terms(words)
            
    result = reference_list[words[0]]
    
    for i in range(1, len(words)):
                result = np.intersect1d(list(result), list(reference_list[words[i]]))
                # result é o resultado de sucessivas buscas OR das palavras
                
    return list(result)

# %% [markdown]
# # Função que trata e identifica a entrada, para selecionar a função de busca

# %%
def search(terms):
    words = terms.lower().split(" ")
    
    if(len(words) == 1):
        return search_one_term(words[0])
        
    if(words[1] == 'or'):
        return search_or_n_terms([words[0],words[2]])
    
    elif(words[1] == 'and'):
            return search_and_n_terms([words[0],words[2]])
        
    else:
        return search_and_n_terms(words)

# %% [markdown]
# # TESTES

# %%
assert len(search("debate OR presidencial")) == 1770

# %%
assert len(search("debate AND presidencial")) == 201

# %%
assert len(search("presidenciáveis OR corruptos")) == 164

# %%
assert len(search("presidenciáveis AND corruptos")) == 0

# %%
assert len(search("Belo OR Horizonte")) == 331

# %%
assert len(search("Belo AND Horizonte")) == 242

# %%
len (search("candidatos"))
# Out:
# 1395

# %%
len(search("PT não pode se queixar afirma futuro articulador"))
# Out:
# 1
